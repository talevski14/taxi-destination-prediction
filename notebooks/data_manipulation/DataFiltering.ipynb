# %%
import pandas as pd

# %%
df = pd.read_parquet("../../data/data.parquet")

# %%
df
# Out:
#                       TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0         1372636858620000589         C          NaN           NaN  20000589
# 1         1372636858620000589         C          NaN           NaN  20000589
# 2         1372636858620000589         C          NaN           NaN  20000589
# 3         1372636858620000589         C          NaN           NaN  20000589
# 4         1372636858620000589         C          NaN           NaN  20000589
# ...                       ...       ...          ...           ...       ...
# 83408412  1404157147620000079         B          NaN          34.0  20000079
# 83408413  1404157147620000079         B          NaN          34.0  20000079
# 83408414  1404157147620000079         B          NaN          34.0  20000079
# 83408415  1404157147620000079         B          NaN          34.0  20000079
# 83408416  1404157147620000079         B          NaN          34.0  20000079
#
# ...

# %%
df_taxi_central_based = df[df['CALL_TYPE'] == 'A']

# %%
df_taxi_central_based
# Out:
#                       TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 398       1372637343620000571         A      31508.0           NaN  20000571
# 399       1372637343620000571         A      31508.0           NaN  20000571
# 400       1372637343620000571         A      31508.0           NaN  20000571
# 401       1372637343620000571         A      31508.0           NaN  20000571
# 402       1372637343620000571         A      31508.0           NaN  20000571
# ...                       ...       ...          ...           ...       ...
# 83407962  1403941536620000213         A      52688.0           NaN  20000213
# 83407963  1403941536620000213         A      52688.0           NaN  20000213
# 83407964  1403941536620000213         A      52688.0           NaN  20000213
# 83407965  1403941536620000213         A      52688.0           NaN  20000213
# 83407966  1403941536620000213         A      52688.0           NaN  20000213
#
# ...

# %%
df['DAY_TYPE'].value_counts()
# Out:
# DAY_TYPE
# A    83408417
# Name: count, dtype: int64

# %%
df_taxi_central_based['DAY_TYPE'].value_counts()
# Out:
# DAY_TYPE
# A    18611037
# Name: count, dtype: int64

# %%
df_taxi_central_based = df_taxi_central_based.drop(columns=['CALL_TYPE', 'ORIGIN_STAND', 'DAY_TYPE', 'MISSING_DATA'], errors='ignore')

# %%
df_taxi_central_based
# Out:
#                       TRIP_ID  ORIGIN_CALL   TAXI_ID   TIMESTAMP  \
# 398       1372637343620000571      31508.0  20000571  1372637343
# 399       1372637343620000571      31508.0  20000571  1372637358
# 400       1372637343620000571      31508.0  20000571  1372637373
# 401       1372637343620000571      31508.0  20000571  1372637388
# 402       1372637343620000571      31508.0  20000571  1372637403
# ...                       ...          ...       ...         ...
# 83407962  1403941536620000213      52688.0  20000213  1403942271
# 83407963  1403941536620000213      52688.0  20000213  1403942286
# 83407964  1403941536620000213      52688.0  20000213  1403942301
# 83407965  1403941536620000213      52688.0  20000213  1403942316
# 83407966  1403941536620000213      52688.0  20000213  1403942331
#
#           POLYLINE_LENGTH       LON        LAT
# 398                    32 -8.618868  41.155101
# 399                    32 -8.617500  41.154912
# ...

# %%
df_taxi_central_based.to_parquet("../../data/data_taxi_central_based.parquet")
